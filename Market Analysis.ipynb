# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\Users\0 Magic\Downloads\archive (8)\Market Basket Analysis.csv")
df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522056  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522057  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522058  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522059  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522060  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                    Date  Price  CustomerID         Country
# 0        12/1/2010 8:26   2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26   3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# # Exploring and Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522061 entries, 0 to 522060
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522061 non-null  int64
#  1   Itemname    520606 non-null  object
#  2   Quantity    522061 non-null  int64
#  3   Date        522061 non-null  object
#  4   Price       522061 non-null  float64
#  5   CustomerID  388023 non-null  float64
#  6   Country     522061 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 27.9+ MB

# %%
df.describe()
# Out:
#               BillNo       Quantity          Price     CustomerID
# count  522061.000000  522061.000000  522061.000000  388023.000000
# mean   559950.785286      10.090488       3.848013   15316.931710
# std     13452.750900     161.110987      32.439440    1721.846964
# min    536365.000000   -9600.000000       0.000000   12346.000000
# 25%    547892.000000       1.000000       1.250000   13950.000000
# 50%    560603.000000       3.000000       2.080000   15265.000000
# 75%    571892.000000      10.000000       4.130000   16837.000000
# max    581587.000000   80995.000000   13541.330000   18287.000000

# %%
df.describe(include='object')
# Out:
#                                   Itemname              Date         Country
# count                               520606            522061          522061
# unique                                4175             19639              30
# top     WHITE HANGING HEART T-LIGHT HOLDER  10/31/2011 14:41  United Kingdom
# freq                                  2269              1114          487619

# %%
#Are there any missing values in the dataset?
df.isnull().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134038
# Country            0
# dtype: int64

# %%
# Drop rows with any missing values
dataset_cleaned = df.dropna()

# %%
#Are there any duplicate rows in the dataset?
dataset_cleaned.duplicated().sum()
# Out:
# 5212

# %%
# Dropping all duplicate rows
dataset_cleaned = dataset_cleaned.drop_duplicates()

# %%
dataset_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382811 entries, 0 to 522060
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      382811 non-null  int64
#  1   Itemname    382811 non-null  object
#  2   Quantity    382811 non-null  int64
#  3   Date        382811 non-null  object
#  4   Price       382811 non-null  float64
#  5   CustomerID  382811 non-null  float64
#  6   Country     382811 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 23.4+ MB

# %%
dataset_cleaned.head()
# Out:
#    BillNo                             Itemname  Quantity            Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/2010 8:26
# 1  536365                  WHITE METAL LANTERN         6  12/1/2010 8:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  12/1/2010 8:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  12/1/2010 8:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  12/1/2010 8:26
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom

# %%
dataset_cleaned['Itemname'].value_counts().sort_values(ascending=False)
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    1964
# REGENCY CAKESTAND 3 TIER              1634
# JUMBO BAG RED RETROSPOT               1588
# ASSORTED COLOUR BIRD ORNAMENT         1378
# PARTY BUNTING                         1362
#                                       ...
# TINY CRYSTAL BRACELET GREEN              1
# BLUE/NAT SHELL NECKLACE W PENDANT        1
# CRACKED GLAZE EARRINGS BROWN             1
# BLACK CHERRY LIGHTS                      1
# PAPER CRAFT  LITTLE BIRDIE               1
# Name: Itemname, Length: 3837, dtype: int64

# %%
dataset_cleaned['Country'].value_counts().sort_values(ascending=False)
# Out:
# United Kingdom          349186
# Germany                   9027
# France                    8327
# Spain                     2480
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1453
# Australia                 1184
# Norway                    1072
# Italy                      758
# Sweden                     450
# Austria                    398
# Poland                     330
# Japan                      321
# Israel                     244
# Unspecified                241
# Singapore                  222
# Iceland                    182
# USA                        179
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Bahrain                     17
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
#creat sales column
dataset_cleaned['Sales'] = dataset_cleaned['Quantity'] * dataset_cleaned['Price']

# %%
profile = ProfileReport(dataset_cleaned, title="Market Sales Report")

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-03-01 22:17:51.122265&quot;&gt;&lt;title&gt;Market Sales Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("market_sales_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
